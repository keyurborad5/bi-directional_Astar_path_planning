# %% [markdown]
# # ENPM661 Project 2
#
# ##### Learning Heapq for Priority queue

# %%
# importing "heapq" to implement heap queue
import heapq

# initializing list
li = [5, 7, 9, 1, 3]

# using heapify to convert list into heap
heapq.heapify(li)

# printing created heap
print ("The created heap is : ",(list(li)))
# Out:
# The created heap is :  [1, 3, 9, 7, 5]

# %%
# importing "heapq" to implement heap queue
import heapq

# initializing list
li = [5, 7, 9, 1, 3]

# using heapify to convert list into heap
heapq.heapify(li)

# printing created heap
print("The created heap is : ", end="")
print(list(li))

# using heappush() to push elements into heap
# pushes 4
heapq.heappush(li, 4)

# printing modified heap
print("The modified heap after push is : ", end="")
print(list(li))

# using heappop() to pop smallest element
print("The popped and smallest element is : ", end="")
print(heapq.heappop(li))

# printing modified heap
print("The modified heap after pop is : ", end="")
print(list(li))
# Out:
# The created heap is : [1, 3, 9, 7, 5]
# The modified heap after push is : [1, 3, 4, 7, 5, 9]
# The popped and smallest element is : 1
# The modified heap after pop is : [3, 5, 4, 7, 9]

# %%
# importing "heapq" to implement heap queue
import heapq

# initializing list 1
li1 = [5, 8, 9, 4, 3]

# initializing list 2
li2 = [5, 7, 9, 4, 3]

# using heapify() to convert list into heap
heapq.heapify(li1)
heapq.heapify(li2)

# using heappushpop() to push and pop items simultaneously
# First push then pop from updated list
# pops 2
print("The popped item using heappushpop() is : ", end="")
print(heapq.heappushpop(li1, 2))

# using heapreplace() to push and pop items simultaneously
# First pop then push from updated list
# pops 3
print("The popped item using heapreplace() is : ", end="")
print(heapq.heapreplace(li2, 2))
print("The popped item using heappop() is : ", end="")
print(heapq.heappop(li2))
# Out:
# The popped item using heappushpop() is : 2
# The popped item using heapreplace() is : 3
# 2

# %%
# Python code to demonstrate working of
# nlargest() and nsmallest()

# importing "heapq" to implement heap queue
import heapq

# initializing list
li1 = [6, 7, 9, 4, 3, 5, 8, 10, 1]

# using heapify() to convert list into heap
heapq.heapify(li1)

# using nlargest to print 3 largest numbers
# prints 10, 9 and 8
print("The 3 largest numbers in list are : ", end="")
print(heapq.nlargest(3, li1))

# using nsmallest to print 3 smallest numbers
# prints 1, 3 and 4
print("The 3 smallest numbers in list are : ", end="")
print(heapq.nsmallest(3, li1))
# Out:
# The 3 largest numbers in list are : [10, 9, 8]
# The 3 smallest numbers in list are : [1, 3, 4]

# %%
import heapq as hq

# creating tuple with cost to come, index, parent node index=0 and coordinate values (x,y) 
d1 = (34, 1, 0, (2,3))  
d2 = (43, 2, 0, (4,5))
d3 = (23, 3, 0, (7,1))

#Initialising the list to be used in priority queue
Q = []

#Push elements to queue
hq.heappush(Q, d1)
hq.heappush(Q, d2)
hq.heappush(Q, d3)
print(Q)
hq.heapify(Q)
print(Q)

first = hq.heappop(Q)
print("First lowest cost element in heap: ", "Cost to come:", first[0], "Parent Node index:", first[1], "Current Index:", first[2], "Coordinates (x,y):", first[3])
first = hq.heappop(Q)
print("Second lowest cost element in heap: ", "Cost to come:", first[0], "Parent Node index:", first[1], "Current Index:", first[2], "Coordinates (x,y):", first[3])
first = hq.heappop(Q)
print("Third lowest cost element in heap: ", "Cost to come:", first[0], "Parent Node index:", first[1], "Current Index:", first[2], "Coordinates (x,y):", first[3])
# Out:
# [(23, 3, 0, (7, 1)), (43, 2, 0, (4, 5)), (34, 1, 0, (2, 3))]
# [(23, 3, 0, (7, 1)), (43, 2, 0, (4, 5)), (34, 1, 0, (2, 3))]
# First lowest cost element in heap:  Cost to come: 23 Parent Node index: 3 Current Index: 0 Coordinates (x,y): (7, 1)
# Second lowest cost element in heap:  Cost to come: 34 Parent Node index: 1 Current Index: 0 Coordinates (x,y): (2, 3)
# Third lowest cost element in heap:  Cost to come: 43 Parent Node index: 2 Current Index: 0 Coordinates (x,y): (4, 5)

# %%
print(Q)
# Out:
# []

# %%
pip install matplotlib
# Out:
# Collecting matplotlibNote: you may need to restart the kernel to use updated packages.
#
#   Using cached matplotlib-3.8.3-cp312-cp312-win_amd64.whl.metadata (5.9 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.2.0-cp312-cp312-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.49.0-cp312-cp312-win_amd64.whl.metadata (162 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.5-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy<2,>=1.21 in e:\university of maryland\sem 2\661 path planning\assisgnments\.enpm661\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in e:\university of maryland\sem 2\661 path planning\assisgnments\.enpm661\lib\site-packages (from matplotlib) (23.2)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-10.2.0-cp312-cp312-win_amd64.whl.metadata (9.9 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in e:\university of maryland\sem 2\661 path planning\assisgnments\.enpm661\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in e:\university of maryland\sem 2\661 path planning\assisgnments\.enpm661\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Using cached matplotlib-3.8.3-cp312-cp312-win_amd64.whl (7.6 MB)
# Using cached contourpy-1.2.0-cp312-cp312-win_amd64.whl (187 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.49.0-cp312-cp312-win_amd64.whl (2.2 MB)
# Using cached kiwisolver-1.4.5-cp312-cp312-win_amd64.whl (56 kB)
# Using cached pillow-10.2.0-cp312-cp312-win_amd64.whl (2.6 MB)
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.2 kB ? eta -:--:--
#    ---------------------------------------  102.4/103.2 kB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 103.2/103.2 kB 1.5 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.0 cycler-0.12.1 fonttools-4.49.0 kiwisolver-1.4.5 matplotlib-3.8.3 pillow-10.2.0 pyparsing-3.1.2

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define boundary
x_min, x_max = -10, 10
y_min, y_max = -10, 10

# Define circle parameters
circle1_center = (0, 0)
circle1_radius = 5
circle2_center = (2, 2)
circle2_radius = 3

# Create grid
x_values = np.linspace(x_min, x_max, 100)
y_values = np.linspace(y_min, y_max, 100)
X, Y = np.meshgrid(x_values, y_values)

# Create obstacle space
obstacle_space = np.zeros_like(X, dtype=bool)

# Evaluate obstacle equations (circles)
obstacle_space[((X - circle1_center[0])**2 + (Y - circle1_center[1])**2) <= circle1_radius**2] = True
obstacle_space[((X - circle2_center[0])**2 + (Y - circle2_center[1])**2) <= circle2_radius**2] = True

# Plot obstacle space
plt.imshow(obstacle_space, extent=(x_min, x_max, y_min, y_max), origin='lower', cmap='gray')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('2D Obstacle Space')
plt.grid(False)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define boundary of the space
x_min, x_max = -10, 10
y_min, y_max = -10, 10

# Define linear inequalities defining the rectangular free space
def in_free_space(x, y):
    return (x >= -5) and (x <= 5) and (y >= -3) and (y <= 3)

# Create grid
x_values = np.linspace(x_min, x_max, 100)
y_values = np.linspace(y_min, y_max, 100)
X, Y = np.meshgrid(x_values, y_values)

# Evaluate inequalities to determine free space
free_space = np.zeros_like(X, dtype=bool)
for i in range(X.shape[0]):
    for j in range(X.shape[1]):
        free_space[i, j] = in_free_space(X[i, j], Y[i, j])

# Plot free space
plt.imshow(free_space, extent=(x_min, x_max, y_min, y_max), origin='lower', cmap='gray')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Semi-Algebraic Model of Free Space')
plt.grid(True)
plt.show()

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in e:\university of maryland\sem 2\661 path planning\assisgnments\.enpm661\lib\site-packages (from opencv-python) (1.26.4)
# Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.9.0.80
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Defining the canvas

# %%
import numpy as np
import cv2
import heapq as hq

# Define canvas size
canvas_height = 300
canvas_width = 600

# Create canvas
canvas = np.zeros((canvas_height, canvas_width, 3), dtype=np.uint8)

# Display canvas shape
print("Canvas shape:", canvas.shape)
# cv2.imshow('window',canvas)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# Out:
(226, 198), (331, 214), (238, 208), (269, 275), (254, 152), (105, 29), (231, 168), (233, 214), (117, 39), (309, 209), (284, 152), (432, 50), (261, 168), (247, 270), (321, 219), (434, 96), (112, 45), (263, 214), (240, 230), (279, 158), (427, 56), (124, 55), (215, 173), (256, 174), (242, 276), (316, 225), (462, 50), (429, 102), (217, 219), (291, 168), (464, 96), (142, 45), (268, 184), (235, 236), (441, 112), (119, 61), (210, 179), (270, 230), (457, 56), (286, 174), (272, 276), (459, 102), (222, 189), (323, 241), (73, 66), (224, 235), (298, 184), (265, 236), (149, 61), (300, 230), (126, 77), (277, 246), (101, 20), (293, 190), (295, 236), (307, 246), (271, 185), (460, 57), (264, 145), (437, 73), (225, 190), (472, 67), (202, 206), (301, 185), (414, 62), (278, 201), (88, 77), (129, 78), (253, 144), (220, 196), (280, 247), (426, 72), (467, 73), (104, 21), (197, 212), (257, 263), (255, 190), (444, 89), (81, 37), (232, 206), (306, 155), (273, 207), (479, 83), (83, 83), (248, 150), (234, 252), (308, 201), (456, 99), (421, 78), (285, 217), (250, 196), (76, 43), (227, 212), (287, 263), (326, 191), (433, 88), (474, 89), (111, 37), (264, 279), (262, 206), (303, 207), (229, 258), (113, 83), (239, 222), (241, 268), (315, 217), (282, 269), (428, 94), (106, 43), (118, 53), (269, 222), (310, 223), (236, 274), (435, 110), (233, 161), (84, 38), (212, 223), (251, 151), (96, 48), (228, 167), (263, 161), (304, 162), (240, 177), (207, 229), (91, 54), (242, 223), (316, 172), (429, 49), (219, 239), (217, 166), (258, 167), (318, 218), (235, 183), (196, 228), (270, 177), ...

# %%
#using Sets
if {(476,78)}.issubset(Obstacle_Space)==False:
    print("yaay")
else: print("NAAYY")
# Out:
# NAAYY

# %%
#using Lists
if (92,88) not in Obstacle_Space:
    print('y')
else:
    print('next')
# Out:
# next

# %%
init_x,init_y=1,150
final_x,final_y=590,150

# %% [markdown]
# ##### Defining Actions as a functions

# %%
# creating tuple with cost to come, node index, parent node index=0 and coordinate values (x,y) 
# creating tuple with cost to come, node index, parent node index=0 and coordinate values (x,y) 
d1 = (34, 1, 0, (5,5))   
def move_up(node):
    c2c=1
    return node[3][0],(node[3][1]+1),1
def move_up_right(node):
    c2c=1.4
    return (node[3][0]+1),(node[3][1]+1),1.4
def move_right(node):
    c2c=1
    return (node[3][0]+1),(node[3][1]),1
def move_down_right(node):
    c2c=1.4
    return (node[3][0]+1),(node[3][1]-1),1.4
def move_down(node):
    c2c=1
    return (node[3][0]),(node[3][1]-1),1
def move_down_left(node):
    c2c=1.4
    return (node[3][0]-1),(node[3][1]-1),1.4
def move_left(node):
    c2c=1
    return (node[3][0]-1),(node[3][1]),1
def move_up_left(node):
    c2c=1.4
    return (node[3][0]-1),(node[3][1]+1),1.4

ctc=0
listt=[move_up,move_right,move_down,move_left,move_up_left,move_down_left,move_down_right,move_up_right]
# for action in listt:
#     print("---------------")
#     d_1=action(d1)
#     print(d_1[:2],d_1[2])

# %%
def cost_to_go(x1,y1,x2,y2):
    return int(((x2-x1)**2+(y2-y1)**2)**(1/2))
hh=((cost_to_go(init_x,init_y,final_x,final_y)))
print(hh)
# Out:
# 589

# %%
# Creating open and closed lists

open_nodes=[]
open_nodes_1=[]

closed_nodes=[]
closed_nodes_1=[]

visited_nodes={}
visited_nodes_1={}

named_node={}
named_node_1={}

hq.heapify(open_nodes)
hq.heapify(open_nodes_1)

hq.heapify(closed_nodes)
hq.heapify(closed_nodes_1)

closed_set=set()
closed_set_1=set()

# closed_set1=set()
# 
# c2c=0
node_index=1
node_index_1=1

parent_node_index=0
parent_node_index_1=0

cost_to_come=0
cost_to_come_1=0

listt=[move_up,move_right,move_down,move_left,move_up_left,move_down_left,move_down_right,move_up_right]

#node =(TC,node_index,parent_node_index,(x,y),c2c,c2g)
start_node=(cost_to_come+cost_to_go(init_x,init_y,final_x,final_y),node_index,parent_node_index,(init_x,init_y),cost_to_come,cost_to_go(init_x,init_y,final_x,final_y))
hq.heappush(open_nodes,start_node)

start_node_1=(cost_to_come_1+cost_to_go(final_x,final_y,init_x,init_y),node_index_1,parent_node_index_1,(final_x,final_y),cost_to_come_1,cost_to_go(init_x,init_y,final_x,final_y))
hq.heappush(open_nodes_1,start_node_1)
#Flag for goal node found
found_goal=False
def visited_node(node):
    visited_nodes.update({node[1]:node[2]})
    named_node.update({node[1]:node[3]})
def visited_node_1(node):
    visited_nodes_1.update({node[1]:node[2]})
    named_node_1.update({node[1]:node[3]})

# %%
while (open_nodes and found_goal!=True):
   
    # Fetching the node with lowest c2c from openlist
    current_node=hq.heappop(open_nodes)
    current_node_1=hq.heappop(open_nodes_1)

    # Pushing the node into closed list
    hq.heappush(closed_nodes,current_node)
    hq.heappush(closed_nodes_1,current_node_1)

    visited_node(current_node)
    visited_node_1(current_node_1)

    closed_set.add(current_node[3])
    closed_set_1.add(current_node_1[3])

    # closed_set1.add(current_node)
    


    # Verifying the fetched node is goal node or not
    # if current_node[3]==(final_x,final_y):
    if current_node[3] in closed_set_1:
        print(current_node)
        parent=current_node[2]
        intersecting_node=current_node[3]
        for key,value in named_node_1.items():
            if intersecting_node==value:
                 parent_1=visited_nodes_1[key]
        #for exiting the loop
        found_goal=True
        ##Backtracking after exiting this while loop
    # If not following code is executed
    elif current_node_1[3] in closed_set:
        print(current_node_1)
        parent_1=current_node_1[2]
        intersecting_node=current_node_1[3]
        for key,value in named_node.items():
            if intersecting_node==value:
                 parent=visited_nodes[key]
        
        #for exiting the loop
        found_goal=True
    else:
        
        # parent_node_index=current_node[2]
        # cost=current_node[0]
        cost_to_come=current_node[4]
        cost_to_come_1=current_node_1[4]

        # heu=current_node[5]

        #iterating all eight actions
        for action in listt:
            action_output=action(current_node)
            # Checking the explored node in the canvas region
            if action_output[0]<600 and action_output[0]>=0 and action_output[1]<300 and action_output[1]>=0:

                new_node=action_output[:2]
                #print(new_node[0],new_node[1])
                action_c2c=action_output[2]
                # heuristic=int(cost_to_go(new_node[0],new_node[1],final_x,final_y))
                heur = cost_to_go(new_node[0],new_node[1],final_x,final_y)
                #Checking if the explored node is not in closed set
                if ({new_node}.issubset(closed_set)==False):
                
                    #Checking if the explored node is not part of obstacle space set
                    if {new_node}.issubset(Obstacle_Space)==False:
                            open_node_flag=False
                            #Iterating explored node through open list
                            for i in range(len(open_nodes)):
                                    if open_nodes[i][3]==new_node:
                                        open_node_flag=True
                                        # updateing the node cost if cost to come is smaller than existing cost to come
                                        if open_nodes[i][0]>(cost_to_come+action_c2c+heur):
                                            open_nodes[i]=(cost_to_come+action_c2c+heur,open_nodes[i][1],current_node[1],open_nodes[i][3],cost_to_come+action_c2c,heur)
                                            break
                                        else:
                                            break
                            # if explored node not found in open list then added
                            if open_node_flag==False:
                                node_index+=1
                                hq.heappush(open_nodes,(cost_to_come+action_c2c+heur,node_index,current_node[1],new_node,cost_to_come+action_c2c,heur))
                            else:#FOr Open_node_falg 
                                pass
                    else:
                        pass#continue    
                else:#For closed_node_flag condition
                    pass# continue        
            
            action_output_1=action(current_node_1)
            # Checking the explored node in the canvas region
            if action_output_1[0]<600 and action_output_1[0]>=0 and action_output_1[1]<300 and action_output_1[1]>=0:

                new_node_1=action_output_1[:2]
                #print(new_node[0],new_node[1])
                action_c2c_1=action_output_1[2]
                # heuristic=int(cost_to_go(new_node[0],new_node[1],final_x,final_y))
                heur_1 = cost_to_go(new_node_1[0],new_node_1[1],init_x,init_y)
                #Checking if the explored node is not in closed set
                if ({new_node_1}.issubset(closed_set_1)==False):
                
                    #Checking if the explored node is not part of obstacle space set
                    if {new_node_1}.issubset(Obstacle_Space)==False:
                            open_node_flag_1=False
                            #Iterating explored node through open list
                            for i in range(len(open_nodes_1)):
                                    if open_nodes_1[i][3]==new_node_1:
                                        open_node_flag_1=True
                                        # updateing the node cost if cost to come is smaller than existing cost to come
                                        if open_nodes_1[i][0]>(cost_to_come_1+action_c2c_1+heur_1):
                                            open_nodes_1[i]=(cost_to_come_1+action_c2c_1+heur_1,open_nodes_1[i][1],current_node_1[1],open_nodes_1[i][3],cost_to_come_1+action_c2c_1,heur_1)
                                            break
                                        else:
                                            break
                            # if explored node not found in open list then added
                            if open_node_flag_1==False:
                                node_index_1+=1
                                hq.heappush(open_nodes_1,(cost_to_come_1+action_c2c_1+heur_1,node_index_1,current_node_1[1],new_node_1,cost_to_come_1+action_c2c_1,heur_1))
                            else:#FOr Open_node_falg 
                                pass
                    else:
                        pass#continue    
                else:#For closed_node_flag condition
                    pass#continue
# Out:
# (593.4, 5268, 5264, (275, 141), 278.4, 315)

# %%
if found_goal==True:
    #Backtracking
    #Visualising the exploration of node

    out = cv2.VideoWriter('keyur_borad_endsem_bi_astar.mp4',cv2.VideoWriter_fourcc(*'mp4v'), 90, (600,300))

    canvas_1=canvas
    count=0
    while closed_nodes or closed_nodes_1:
        if closed_nodes:
            plot=hq.heappop(closed_nodes)
        if closed_nodes_1:
            plot_1=hq.heappop(closed_nodes_1)

        #plotting initial point
        cv2.circle(canvas_1, (init_x,init_y), 4, [0,0,252], -1)
        #plotting final point
        cv2.circle(canvas_1, (final_x,final_y), 4, [0,255,0], -1)
        #PLotting the explored node
        cv2.circle(canvas_1, (plot[3][0],plot[3][1]), 1, [250,0,0], -1)
        cv2.circle(canvas_1, (plot_1[3][0],plot_1[3][1]), 1, [0,0,255], -1)

        # counter for speeding up the display
        if count%100==0:
            out.write(canvas_1)
            cv2.imshow('window',canvas_1)
            cv2.waitKey(1)
        count+=1

    # Visualising Backtracking 
    # parent= current_node[2]
    # print(parent)
    backtrack=[]
    while parent!=0:
        backtrack.append(named_node[parent])
        parent=visited_nodes[parent]
    backtrack.reverse()
    backtrack_1=[]
    while parent_1!=0:
        backtrack_1.append(named_node_1[parent_1])
        parent_1=visited_nodes_1[parent_1]
    # backtrack.reverse()
    for coord in (backtrack):
        #ploting the backtracked points
        cv2.circle(canvas_1, (coord[0],coord[1]), 1, [0,250,0], -1)
        out.write(canvas_1)
        cv2.imshow('window',canvas_1)
        cv2.waitKey(1)
    for coord in (backtrack_1):
        #ploting the backtracked points
        cv2.circle(canvas_1, (coord[0],coord[1]), 1, [0,250,0], -1)
        out.write(canvas_1)
        cv2.imshow('window',canvas_1)
        cv2.waitKey(1)
    '''
    Loop to add some additional frames at the end of the video
    '''
    for i in range(150):
        out.write(canvas_1)                               # write the frame to video
    
    cv2.waitKey(0)
    out.release()
    cv2.destroyAllWindows()
# end_time = time.time()
# print(f"The runtime of my program is {end_time - start_time} seconds.")

# %%
print(intersecting_node)
print(current_node)
print(current_node_1)
# Out:
# (275, 141)
# (602.4, 5268, 5264, (275, 141), 278.4, 324)
# (601.5999999999999, 5200, 4601, (343, 159), 259.59999999999997, 342)

# %%
for key,value in named_node_1.items():
    if intersecting_node==value:
        print(key,value)
# Out:
# 5797 (275, 141)

# %%
print(len(named_node_1))
# Out:
# 0

# %% [markdown]
# ##### Consolidated Program

# %%
import heapq as hq
def move_up(node):
    return node[3][0],(node[3][1]+1),1
def move_up_right(node):
    return (node[3][0]+1),(node[3][1]+1),1.4
def move_right(node):
    return (node[3][0]+1),(node[3][1]),1
def move_down_right(node):
    return (node[3][0]+1),(node[3][1]-1),1.4
def move_down(node):
    return (node[3][0]),(node[3][1]-1),1
def move_down_left(node):
    return (node[3][0]-1),(node[3][1]-1),1.4
def move_left(node):
    return (node[3][0]-1),(node[3][1]),1
def move_up_left(node):
    return (node[3][0]-1),(node[3][1]+1),1.4

listt=[move_up,move_right,move_down,move_left,move_up_left,move_down_left,move_down_right,move_up_right]

# Creating open and closed lists

open_nodes=[]
closed_nodes=[]
visited_nodes={}
named_node={}
hq.heapify(open_nodes)
hq.heapify(closed_nodes)
closed_set=set()
closed_set1=set()

c2c=0
node_index=1
parent_node_index=0
cost_to_come=0
start_node=(cost_to_come,node_index,parent_node_index,(init_x,init_y))
hq.heappush(open_nodes,start_node)

#Flag for goal node found
found_goal=False
def visited_node(node):
    visited_nodes.update({node[1]:node[2]})
    named_node.update({node[1]:node[3]})

while (open_nodes and found_goal!=True):
    ######################
    #Checking termination of while loop
    # print(hq.heappop(open_nodes))
    #Checking termination of while loop
    # i+=1
    # print(i)
    # if i==10:
    #     found_goal=True
    ######################
    # Fetching the node with lowest c2c from openlist
    current_node=hq.heappop(open_nodes)
    # Pushing the node into closed list
    hq.heappush(closed_nodes,current_node)
    visited_node(current_node)
    closed_set.add(current_node[3])
    closed_set1.add(current_node)
    


    # Verifying the fetched node is goal node or not
    if current_node[3]==(final_x,final_y):
        print(current_node)
        found_goal=True
        ##Backtracking after exiting this while loop
    # If not following code is executed
    else:
        
        parent_node_index=current_node[2]
        cost_to_come=current_node[0]
        for action in listt:
            action_output=action(current_node)
            if action_output[0]<=1194 and action_output[0]>=5 and action_output[1]<=494 and action_output[1]>=5:

                new_node=action_output[:2]
                action_c2c=action_output[2]
                if ({new_node}.issubset(closed_set)==False):
                
                
                    if {new_node}.issubset(Obstacle_Space)==False:
                            open_node_flag=False
                            for i in range(len(open_nodes)):
                                    if open_nodes[i][3]==new_node:
                                        open_node_flag=True
                                        if open_nodes[i][0]>(cost_to_come+action_c2c):
                                            open_nodes[i]=(cost_to_come+action_c2c,open_nodes[i][1],current_node[1],open_nodes[i][3])
                                            break
                                        else:
                                            break
                            
                            if open_node_flag==False:
                                node_index+=1
                                hq.heappush(open_nodes,(cost_to_come+action_c2c,node_index,current_node[1],new_node))
                            else:#FOr Open_node_falg 
                                pass
                    else:
                        continue    
                else:#For closed_node_flag condition
                    continue        


                    
        
   

# if found_goal==True:
    #Backtracking
# Out:
# (1471.9999999999973, 354441, 354158, (1190, 450))

# %% [markdown]
# ##### Visualatizing the node exploration and Backtracking (Consolidated)

# %%
#Visualising the exploration of node

out = cv2.VideoWriter('keyur_borad_project2.avi',cv2.VideoWriter_fourcc('M','J','P','G'), 10, (1200,500))

canvas_1=canvas
count=0
while closed_nodes:
    plot=hq.heappop(closed_nodes)
    
    cv2.circle(canvas_1, (init_x,500-init_y), 4, [0,0,252], -1)
    cv2.circle(canvas_1, (final_x,500-final_y), 4, [0,0,250], -1)
    cv2.circle(canvas_1, (plot[3][0],500-plot[3][1]), 1, [250,0,0], -1)
    
    if count%100==0:
        out.write(canvas_1)
        cv2.imshow('window',canvas_1)
        cv2.waitKey(1)
    count+=1

# Visualising Backtracking 
parent= current_node[2]
print(parent)
backtrack=[]
while parent!=0:
    backtrack.append(named_node[parent])
    parent=visited_nodes[parent]
backtrack.reverse()
for coord in (backtrack):
    cv2.circle(canvas_1, (coord[0],500-coord[1]), 1, [0,250,0], -1)
    out.write(canvas_1)
    cv2.imshow('window',canvas_1)
    cv2.waitKey(1)
cv2.waitKey(0)
out.release()
cv2.destroyAllWindows()
# Out:
# 354158

# %%
print(backtrack.reverse())
# Out:
# None

# %%
print(backtrack)
# Out:
# [(1190, 450), (1189, 450), (1188, 450), (1187, 450), (1186, 450), (1185, 450), (1184, 450), (1183, 450), (1182, 450), (1181, 450), (1180, 450), (1179, 450), (1178, 450), (1177, 450), (1176, 450), (1175, 450), (1174, 450), (1173, 450), (1172, 450), (1171, 450), (1170, 450), (1169, 450), (1168, 450), (1167, 450), (1166, 450), (1165, 450), (1164, 450), (1163, 450), (1162, 450), (1161, 450), (1160, 450), (1159, 450), (1158, 450), (1157, 450), (1156, 450), (1155, 450), (1154, 450), (1153, 450), (1152, 450), (1151, 450), (1150, 450), (1149, 450), (1148, 450), (1147, 450), (1146, 450), (1145, 450), (1144, 450), (1143, 450), (1142, 450), (1141, 450), (1140, 450), (1139, 450), (1138, 450), (1137, 450), (1136, 450), (1135, 450), (1134, 450), (1133, 450), (1132, 451), (1131, 452), (1130, 453), (1129, 454), (1128, 455), (1127, 456), (1126, 456), (1
# %%
# Backtracking with iterating over list
# canvas_1=canvas
# parent= current_node[2]
# backtrack=[]
# while parent!=0:
#     for nodees in closed_nodes:
#         if nodees[1]==parent:
#             backtrack.append(nodees[3])
#             cv2.circle(canvas_1, (nodees[3][0],500-nodees[3][1]), 1, [0,255,0], -1)
#             parent=nodees[2]

# cv2.imshow('window',canvas_1)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# Backtracking with iterating over SET
# canvas_1=canvas
# parent= current_node[2]
# backtrack=[]
# while parent!=0:
#     for nodees in closed_set1:
#         if nodees[1]==parent:
#             backtrack.append(nodees[3])
#             cv2.circle(canvas_1, (nodees[3][0],500-nodees[3][1]), 1, [0,255,0], -1)
#             parent=nodees[2]

# cv2.imshow('window',canvas_1)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# Backtracking with iterating over Dictionary
# canvas_1=canvas
# parent= current_node[2]
# print(parent)
# backtrack=[]
# while parent!=0:
#     coord=named_node[parent]
#     backtrack.append(named_node[parent])
#     parent=visited_nodes[parent]
#     cv2.circle(canvas_1, (coord[0],500-coord[1]), 1, [0,250,0], -1)
#     # count=0
#     # while count!=99999:
#     #     count+=1
#     cv2.imshow('window',canvas_1)
#     cv2.waitKey(1)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# print(backtrack)

# Backtracking with iterating over Dictionary
#Reversing the visualization
parent= current_node[2]
print(parent)
backtrack=[]
while parent!=0:
    backtrack.append(named_node[parent])
    parent=visited_nodes[parent]
backtrack.reverse()
for coord in (backtrack):
    cv2.circle(canvas_1, (coord[0],500-coord[1]), 1, [0,250,0], -1)
    cv2.imshow('window',canvas_1)
    cv2.waitKey(1)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 429445

# %%
# Visualising Backtracking 
parent= current_node[2]
print(parent)
backtrack=[]
while parent!=0:
    backtrack.append(named_node[parent])
    parent=visited_nodes[parent]
backtrack.reverse()
for coord in (backtrack):
    
    cv2.circle(canvas_1, (coord[0],500-coord[1]), 1, [0,250,0], -1)
    cv2.imshow('window',canvas_1)
    cv2.waitKey(1)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 362357

# %%
cv2.imshow('win',canvas_1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
print(backtrack)
# Out:
# [(64, 300), (63, 300), (62, 300), (61, 300), (60, 300)]

# %%
for ele in closed_nodes:
    if ele[3][1]<=0:
        print(ele[3])

# %%
diction={200:{12:{2:(10,20)}}}
print(diction[200][12][2])
# Out:
# (10, 20)

# %% [markdown]
# There are four collection data types in the Python programming language:
#
# List is a collection which is ordered and changeable. Allows duplicate members.
#
# Tuple is a collection which is ordered and unchangeable. Allows duplicate members.
#
# Set is a collection which is unordered, unchangeable*, and unindexed. No duplicate members.
#
# Dictionary is a collection which is ordered** and changeable. No duplicate members.

# %%
aa=[(1000,2),(3000,4),(5,6),(7,22),(3,1)]
print(type(aa))
aa=set(aa)
bb=set([(3000,4),(5,6)])

print(type(aa))
print(aa)
print(bb.issubset(aa))
# Out:
# <class 'list'>
# <class 'set'>
# {(3, 1), (7, 22), (3000, 4), (5, 6), (1000, 2)}
# False

# %%
ss=set()
print(type(ss))
# Out:
# <class 'set'>

# %%
ss.add(2)
print(ss)
# Out:
# {2}

# %%
ss.add("good")
print(ss)
# Out:
# {'good', 2}

# %%
print(ss.pop())
# Out:
# good
